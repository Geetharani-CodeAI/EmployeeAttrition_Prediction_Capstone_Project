# %%
import pickle
import pandas as pd
loaded_model = pickle.load(open('Attrition_Prediction_Dataset.sav','rb'))

# %%
data = {
    'Age': int(input('Age: ')),
    'DailyRate': int(input('DailyRate: ')),
    'DistanceFromHome': int(input('DistanceFromHome: ')),
    'Education': int(input('Education (1–5): ')),
    'EnvironmentSatisfaction': int(input('EnvironmentSatisfaction (1–4): ')),
    'HourlyRate': int(input('HourlyRate (30-100):')),
    'JobInvolvement': int(input('JobInvolvement (1–4): ')),
    'JobLevel': int(input('JobLevel (1–5): ')),
    'JobSatisfaction': int(input('JobSatisfaction (1–4): ')),
    'MonthlyIncome': int(input('MonthlyIncome: ')),
    'MonthlyRate': int(input('MonthlyRate: ')),
    'NumCompaniesWorked': int(input('NumCompaniesWorked: ')),
    'PercentSalaryHike': int(input('PercentSalaryHike: ')),
    'PerformanceRating': int(input('PerformanceRating (1–4): ')),
    'RelationshipSatisfaction': int(input('RelationshipSatisfaction (1–4): ')),
    'StockOptionLevel': int(input('StockOptionLevel (0–3): ')),
    'TotalWorkingYears': int(input('TotalWorkingYears: ')),
    'TrainingTimesLastYear': int(input('TrainingTimesLastYear: ')),
    'WorkLifeBalance': int(input('WorkLifeBalance (1–4): ')),
    'YearsAtCompany': int(input('YearsAtCompany: ')),
    'YearsInCurrentRole': int(input('YearsInCurrentRole: ')),
    'YearsSinceLastPromotion': int(input('YearsSinceLastPromotion: ')),
    'YearsWithCurrManager': int(input('YearsWithCurrManager: ')),
    'BusinessTravel_Travel_Frequently': int(input('BusinessTravel_Travel_Frequently (1/0): ')),
    'BusinessTravel_Travel_Rarely': int(input('BusinessTravel_Travel_Rarely (1/0): ')),
    'Department_Research & Development': int(input('Department_Research & Development (1/0): ')),
    'Department_Sales': int(input('Department_Sales (1/0): ')),
    'EducationField_Life Sciences': int(input('EducationField_Life Sciences (1/0): ')),
    'EducationField_Marketing': int(input('EducationField_Marketing (1/0): ')),
    'EducationField_Medical': int(input('EducationField_Medical (1/0): ')),
    'EducationField_Other': int(input('EducationField_Other (1/0): ')),
    'EducationField_Technical Degree': int(input('EducationField_Technical Degree (1/0): ')),
    'Gender_Male': int(input('Gender_Male (1=Male, 0=Female): ')),
    'JobRole_Human Resources': int(input('JobRole_Human Resources (1/0): ')),
    'JobRole_Laboratory Technician': int(input('JobRole_Laboratory Technician (1/0): ')),
    'JobRole_Manager': int(input('JobRole_Manager (1/0): ')),
    'JobRole_Manufacturing Director': int(input('JobRole_Manufacturing Director (1/0): ')),
    'JobRole_Research Director': int(input('JobRole_Research Director (1/0): ')),
    'JobRole_Research Scientist': int(input('JobRole_Research Scientist (1/0): ')),
    'JobRole_Sales Executive': int(input('JobRole_Sales Executive (1/0): ')),
    'JobRole_Sales Representative': int(input('JobRole_Sales Representative (1/0): ')),
    'MaritalStatus_Married': int(input('MaritalStatus_Married (1/0): ')),
    'MaritalStatus_Single': int(input('MaritalStatus_Single (1/0): ')),
    'OverTime_Yes': int(input('OverTime_Yes (1=Yes, 0=No): '))
}
# Out:
# Age:  31
# DailyRate:  234
# DistanceFromHome:  3
# Education (1–5):  5
# EnvironmentSatisfaction (1–4):  4
# HourlyRate (30-100): 50
# JobInvolvement (1–4):  4
# JobLevel (1–5):  4
# JobSatisfaction (1–4):  4
# MonthlyIncome:  4567
# MonthlyRate:  456789
# NumCompaniesWorked:  3
# PercentSalaryHike:  12
# PerformanceRating (1–4):  3
# RelationshipSatisfaction (1–4):  4
# StockOptionLevel (0–3):  0
# TotalWorkingYears:  3
# TrainingTimesLastYear:  2
# WorkLifeBalance (1–4):  3
# YearsAtCompany:  2
# YearsInCurrentRole:  2
# YearsSinceLastPromotion:  1
# YearsWithCurrManager:  1
# BusinessTravel_Travel_Frequently (1/0):  1
# BusinessTravel_Travel_Rarely (1/0):  0
# Department_Research & Development (1/0):  0
# Department_Sales (1/0):  0
# EducationField_Life Sciences (1/0):  1
# EducationField_Marketing (1/0):  0
# EducationField_Medical (1/0):  0
# EducationField_Other (1/0):  1
# EducationField_Technical Degree (1/0):  0
# Gender_Male (1=Male, 0=Female):  0
# ...

# %%
df = pd.DataFrame([data])
prediction = loaded_model.predict(df)
print("\nPredicted Attrition:", "Yes" if prediction[0] == 1 else "No")
prediction
# Out:
# Predicted Attrition: Yes
# C:\Users\Hxtreme\.conda\envs\AIML\Lib\site-packages\sklearn\utils\validation.py:2742: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# array([1])
